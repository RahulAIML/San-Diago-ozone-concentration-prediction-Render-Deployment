# %%
import pandas as pd

df = pd.read_csv('D:\Ozone_Project_7th_dec\predictionlog.csv')
print(df.head())
# Out:
#    id                                         input_data  \
# 0   1  {"ozone_lag_1": 40, "tmax": 25, "tavg": 20, "C...
# 1   2  {"ozone_lag_1": 40, "tmax": 25, "tavg": 20, "C...
# 2   3  {"ozone_lag_1": 40, "tmax": 25, "tavg": 20, "C...
# 3   4  {"ozone_lag_1": 40, "tmax": 25, "tavg": 20, "C...
#
#                                     predicted_output  \
# 0  {"predicted_ozone": 39.64148712158203, "air_qu...
# 1  {"predicted_ozone": 35.94423294067383, "air_qu...
# 2  {"predicted_ozone": 36.09300231933594, "air_qu...
# 3  {"predicted_ozone": 37.06261444091797, "air_qu...
#
#                    created_at
# 0  2025-12-20 04:27:00.227193
# 1  2025-12-20 04:28:14.175598
# 2  2025-12-20 04:43:31.207991
# 3  2025-12-20 05:03:02.637358
# <>:3: SyntaxWarning: invalid escape sequence '\O'
# <>:3: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\User\AppData\Local\Temp\ipykernel_24020\4031660086.py:3: SyntaxWarning: invalid escape sequence '\O'
# ...
